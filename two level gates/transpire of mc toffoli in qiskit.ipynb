# %%
import numpy as np
from qiskit import *
from numpy.linalg import inv

# %%
qc = QuantumCircuit(5)
qc.mcx([0,1,2,3],4)
qc.draw('mpl')

# %%
tmct = transpile(qc, basis_gates=['cx','h','p'], optimization_level = 3)
#tmct.draw('mpl')

# %%
tmct.draw('mpl')
